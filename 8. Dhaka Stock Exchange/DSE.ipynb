# %%
import pandas as pd

# %%
dse = pd.read_csv("DSE_010119.csv")

# %%
dse
# Out:
#                              00DSEX  01-01-2019  5385.64  5474.50  5385.64.1  \
# 0                            00DS30  01-01-2019  1880.78  1911.37    1880.78
# 1                            00DSES  01-01-2019  1232.82  1247.50    1232.82
# 2                              DSEX  01-01-2019  5385.64  5474.50    5385.64
# 3                              DS30  01-01-2019  1880.78  1911.37    1880.78
# 4                              DSES  01-01-2019  1232.82  1247.50    1232.82
# 5                         1JANATAMF  01-01-2019     4.50     4.60       4.40
# 6                        1STPRIMFMF  01-01-2019    10.80    10.90      10.70
# 7                          AAMRANET  01-01-2019    59.80    60.70      58.80
# 8                         AAMRATECH  01-01-2019    29.10    29.40      28.80
# 9                          ABB1STMF  01-01-2019     4.50     4.60       4.50
# 10                           ABBANK  01-01-2019    12.00    12.10      11.80
# ...
