# %% [markdown]
# # wine magazine data analysis using pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_path = "winemag_data_first150k.csv"
wine_data = pd.read_csv(data_path, index_col=0)
wine_data.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
wine_data.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
wine_data.shape
# Out:
# (150930, 10)

# %%
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
# country        150925 non-null object
# description    150930 non-null object
# designation    105195 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# winery         150930 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 12.7+ MB

# %% [markdown]
# # Univariate plotting

# %% [markdown]
# # 1. Bar plot

# %% [markdown]
# ## 1.1 the labels of wines the countries produce (number)

# %%
plt.figure(figsize=(16,6))
wine_data['country'].value_counts().head(10).plot.bar()

# %% [markdown]
# ## 1.2 the labels of wines the countries produce in percentage

# %%
plt.figure(figsize=(16,6))
(wine_data["country"].value_counts().head(10)/len(wine_data)*100).plot.bar()

# %% [markdown]
# ## 1.3 the labels of wines the provinces produce in percentage

# %%
plt.figure(figsize=(16,6))
(wine_data["province"].value_counts().head(20)/len(wine_data)*100).plot.bar()

# %% [markdown]
# ##  1.4 the number of reviews of a certain points

# %%
plt.figure(figsize=(16,6))
wine_data['points'].value_counts().sort_index().plot.bar()
#Adjusting title, fontsize using Matplotlib
plt.title("Count of wine points", fontsize=16)
plt.xlabel("Points")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # 2. Line charts

# %% [markdown]
# ## 2.1  the number of reviews of a certain points in line chart

# %%
plt.figure(figsize=(16,6))
wine_data['points'].value_counts().sort_index().plot.line()
plt.xlabel("Points")
plt.ylabel("Reviews")
# Out:
# Text(0, 0.5, 'Reviews')

# %% [markdown]
# ## 2.2  the number of reviews of a certain points in area chart

# %%
plt.figure(figsize=(16,6))
wine_data['points'].value_counts().sort_index().plot.area()
plt.xlabel("Points")
plt.ylabel("Reviews")
# Out:
# Text(0, 0.5, 'Reviews')

# %% [markdown]
# ## 2.3 number of different prices showed in line chart

# %%
plt.figure(figsize=(16,6))
wine_data['price'].value_counts().sort_index().plot.line()
plt.xlabel("Price")
plt.ylabel("Production")
# Out:
# Text(0, 0.5, 'Production')

# %% [markdown]
# ## 2.4 low prices wines produce most or get more popularities/reviews

# %%
plt.figure(figsize=(16,6))
wine_data['price'].value_counts().head(100).sort_index().plot.line()
plt.xlabel("Price")
plt.ylabel("Production")
# Out:
# Text(0, 0.5, 'Production')

# %% [markdown]
# # 3. Subplot

# %%
#Creating a frame of rows and columns to place the plots
fig, axi = plt.subplots(1,3, figsize = (16,3))
#plot1
wine_data['points'].value_counts().plot.bar(ax = axi[0])
axi[0].set_title("Count points of Wine")
#Plot2
wine_data['country'].value_counts().head(10).plot.bar(ax = axi[1])
axi[1].set_title('Country')
#plot3
wine_data['winery'].value_counts().head(10).plot.bar(ax = axi[2])
axi[2].set_title("No of Wines from Winery")
# Out:
# Text(0.5, 1.0, 'No of Wines from Winery')

# %% [markdown]
# # 4. Histograms

# %%
plt.figure(figsize=(16,6))
wine_data["points"].plot.hist()

# %%
plt.figure(figsize=(16,6))
wine_data["price"].plot.hist()

# %%
plt.figure(figsize=(16,6))
wine_data[wine_data["price"] <= 100]["price"].plot.hist()

# %%
plt.figure(figsize=(16,6))
wine_data[wine_data["price"] >= 1000]["price"].plot.hist()
wine_data[wine_data["price"] >= 1000]
# Out:
#        country                                        description  \
# 10651  Austria  Wet earth, rain-wet stones, damp moss, wild sa...
# 13318       US  The nose on this single-vineyard wine from a s...
# 26296   France  A wine that has created its own universe. It h...
# 34920   France  A big, powerful wine that sums up the richness...
# 34922   France  A massive wine for Margaux, packed with tannin...
# 34927   France  Such a generous and ripe wine, with a dark cor...
# 34939   France  The purest Cabernet Sauvignon fruit, with dark...
# 34942   France  Solid, very structured, packed with dense and ...
# 35531   France  This is the first vintage of a wine that used ...
# 51886   France  A wine that has created its own universe. It h...
# 83536   France  A wine that has created its own universe. It h...
#
#                    designation  points   price    province        region_1  \
# 10651  Ried Loibenberg Smaragd      94  1100.0      Wachau             NaN
# 13318      Roger Rose Vineyard      91  2013.0  California     Arroyo Seco
# 26296           Clos du Mesnil     100  1400.0   Champagne       Champagne
# 34920                      NaN      99  2300.0    Bordeaux        Pauillac
# 34922                      NaN      98  1900.0    Bordeaux         Margaux
# 34927                      NaN      97  1100.0    Bordeaux  Pessac-Léognan
# 34939                      NaN      96  1300.0    Bordeaux        Pauillac
# 34942                      NaN      96  1200.0    Bordeaux  Pessac-Léognan
# 35531                      NaN      94  1000.0    Bordeaux  Pessac-Léognan
# 51886           Clos du Mesnil     100  1400.0   Champagne       Champagne
# 83536           Clos du Mesnil     100  1400.0   Champagne       Champagne
#
#             region_2                     variety  \
# 10651            NaN            Grüner Veltliner
# 13318  Central Coast                  Chardonnay
# 26296            NaN                  Chardonnay
# 34920            NaN    Bordeaux-style Red Blend
# 34922            NaN    Bordeaux-style Red Blend
# 34927            NaN    Bordeaux-style Red Blend
# 34939            NaN    Bordeaux-style Red Blend
# 34942            NaN    Bordeaux-style Red Blend
# 35531            NaN  Bordeaux-style White Blend
# 51886            NaN                  Chardonnay
# 83536            NaN                  Chardonnay
#
#                               winery
# 10651                 Emmerich Knoll
# 13318                          Blair
# 26296                           Krug
# 34920                 Château Latour
# 34922                Château Margaux
# 34927  Château La Mission Haut-Brion
# 34939      Château Mouton Rothschild
# 34942             Château Haut-Brion
# 35531  Château La Mission Haut-Brion
# 51886                           Krug
# 83536                           Krug

# %% [markdown]
# # 5. pie plot

# %%
plt.figure(figsize=(10,10))
wine_data["country"].value_counts().head(10).plot.pie()
plt.gca().set_aspect('equal')

# %%
plt.figure(figsize=(10,10))
wine_data["province"].value_counts().head(10).plot.pie()
plt.gca().set_aspect('equal')

# %%
plt.figure(figsize=(10,10))
wine_data["variety"].value_counts().head(10).plot.pie()
plt.gca().set_aspect('equal')

# %% [markdown]
# # Bivariate plotting

# %% [markdown]
# # 6. Scatter plot

# %%
wine_data.plot.scatter(x="price", y="points", figsize=(16,6))

# %%
wine_data[wine_data["price"] <= 150].plot.scatter(x="price", y="points", figsize=(16,6))

# %% [markdown]
# # 7. Hex plot

# %%
wine_data[wine_data["price"] <= 100].plot.hexbin(x="price", y="points", gridsize=20, figsize=(16,10))
