# %% [markdown]
# # Ploting x, y, z co-ordinates

# %%
from matplotlib import pyplot as plt

# %%
x = [2, 5, 8]
y = [7, 3, 15]
z = [22, -5, 22]
plt.plot(x,y)
plt.plot(x,z)
plt.title("x, y, z plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["x vs y", "x vs z"])
plt.show()
