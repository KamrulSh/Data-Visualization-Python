# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("dataset_3.csv")
data.head()
# Out:
#      X1     X2    Good     Bad
# 0 -9.97 -19.93  294.32  429.40
# 1  7.51  15.03  109.04  198.18
# 2 -2.52  -5.04 -173.61  -35.08
# 3  4.92   9.85  -65.99   66.42
# 4  6.88  13.77   10.76  155.46

# %%
plt.figure(figsize=(12,6))
plt.plot(data["X1"], data["Bad"], "^", label="Bad")            
plt.plot(data["X1"], data["Good"], "+", label="Good")
plt.legend()

# %%
plt.figure(figsize=(12,6))
plt.plot(data["X2"], data["Bad"], "^", label="Bad")            
plt.plot(data["X2"], data["Good"], "+", label="Good")
plt.legend()
